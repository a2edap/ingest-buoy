# %%
import xarray as xr

ds = xr.open_dataset(
    "../../storage/root/data/morro.buoy_z06-imu.a1/morro.buoy_z06-imu.a1.20201201.000011.nc"
)

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:              (time: 17910, direction: 3)
# Coordinates:
#   * time                 (time) datetime64[ns] 2020-12-01T00:00:11.164999936 ...
#   * direction            (direction) object 'x' 'y' 'z'
# Data variables: (12/14)
#     roll                 (time) float64 ...
#     pitch                (time) float64 ...
#     yaw                  (time) float64 ...
#     angular_velocity     (time, direction) float64 ...
#     acceleration         (time, direction) float64 ...
#     magnetic_field       (time, direction) float64 ...
#     ...                   ...
#     qc_pitch             (time) int32 ...
#     qc_yaw               (time) int32 ...
#     qc_angular_velocity  (time, direction) int32 ...
#     qc_acceleration      (time, direction) int32 ...
#     qc_magnetic_field    (time, direction) int32 ...
#     qc_pressure          (time) int32 ...
# Attributes:
#     title:             IMU Buoy Pipeline
# ...
